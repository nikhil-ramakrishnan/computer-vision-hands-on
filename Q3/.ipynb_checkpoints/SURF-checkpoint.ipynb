# %%
#SURF
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in d:\python\lib\site-packages (1.22.4)
# WARNING: Ignoring invalid distribution -rotobuf (d:\python\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\python\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\python\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\python\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\python\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\python\lib\site-packages)

# %%
import mahotas
import mahotas.demos
import mahotas as mh
import numpy as np
import cv2 as cv
from pylab import imshow, show
from mahotas.features import surf
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0x10 but this version of numpy is 0xf
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [3], in <cell line: 7>()
#       5 import cv2 as cv
#       6 from pylab import imshow, show
# ----> 7 from mahotas.features import surf
#
# File D:\python\lib\site-packages\mahotas\features\__init__.py:6, in <module>
#       1 # -*- coding: utf-8 -*-
#       2 # Copyright (C) 2012-2014, Luis Pedro Coelho <luis@luispedro.org>
#       3 # vim: set ts=4 sts=4 sw=4 expandtab smartindent:
#       4 #
# ----> 6 from .texture import haralick
#       7 from .tas import tas, pftas
#       8 from .zernike import zernike, zernike_moments
#
# File D:\python\lib\site-packages\mahotas\features\texture.py:8, in <module>
#       1 # Copyright (C) 2008-2016, Luis Pedro Coelho <luis@luispedro.org>
#       2 # vim: set ts=4 sts=4 sw=4 expandtab smartindent:
#       3 #
#       4 # License: MIT (see COPYING file)
#       7 import numpy as np
# ----> 8 from . import _texture
#       9 from ..internal import _verify_is_integer_type
#      11 __all__ = [
#      12     'haralick',
#      13     'haralick_labels',
#      14     'cooccurence',
#      15     ]
#
# ImportError: numpy.core.multiarray failed to import

# %%
f = mh.imread('dataset/image1.jpeg', as_grey=True)
f = f.astype(np.uint8)
spoints = surf.surf(f)
print("Nr points:", len(spoints))
# Out:
# Nr points: 1015

# %%
from sklearn.cluster import KMeans
km = KMeans(
    n_clusters=5, init='random',
    n_init=10, max_iter=300, 
    tol=1e-04, random_state=0
)
values = km.fit_predict(spoints)
colors = np.array([(255-52*i,25+52*i,37**i % 101) for i in range(5)])

# %%
img2 = surf.show_surf(f, spoints, values, colors)

# %%
imshow(img2)

# %%
#reference https://mahotas.readthedocs.io/en/latest/surf.html
